# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))

# %%
# Train the product image classifier (HOG + SVM baseline).
from training.train_product_classifier import main
main()
