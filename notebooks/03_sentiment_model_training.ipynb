# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))

# %%
# Train the TF-IDF + Logistic Regression sentiment model.
from training.train_sentiment_model import main
main()
